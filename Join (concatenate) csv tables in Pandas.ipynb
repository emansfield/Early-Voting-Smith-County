# %% [markdown]
# ### Introduction to pandas!
#
# What we will learn in this notebook:
# - how to open and read in a csv spreadsheet
# - how to look at the data we have
# - how to select columns
# - how to do some math with them

# %% [markdown]
# First we need to import pandas as a library. We import the library and then tell Python to refer to it as `pd`:

# %%
import pandas as pd
import matplotlib.pyplot as plot
import numpy 
import seaborn 
import datetime

# %% [markdown]
# ### Reading spreadsheets
#
# This is how you read a spreadsheet and assign it to a variable:

# %%
# Bring in all my spreadsheets 
ev_1022 = pd.read_csv('Voted-Early-10222018.csv')
ev_1023 = pd.read_csv('Voted-Early-10232018.csv')
ev_1024 = pd.read_csv('Voted-Early-10242018.csv')
ev_1025 = pd.read_csv('Voted-Early-10252018.csv')
ev_1026 = pd.read_csv('Voted-Early-10262018.csv')
ev_1027 = pd.read_csv('Voted-Early-10272018.csv')
ev_1029 = pd.read_csv('Voted-Early-10292018.csv')
ev_1030 = pd.read_csv('Voted-Early-10302018.csv')
ev_1031 = pd.read_csv('Voted-Early-10312018.csv')
ev_1101 = pd.read_csv('Voted-Early-11012018.csv')
ev_1102 = pd.read_csv('Voted-Early-11022018.csv')

# %% [markdown]
# ### Looking at your data
#
# To look at the data you just read into Python, you can just run a cell with the name of the variable:

# %%
ev_1022.head(5)
# Out:
#            ID        CERT LASTNAME FIRSTNAME MIDDLENAME SUFFIX  \
# 0  1205658124  1205658124    ABBEY       IAN     ISSARA    NaN
# 1  1057082649  1057082649     ABEL     PAULA       ROSE    NaN
# 2  1129020391  1129020391  ABRAHAM     CAROL        ANN    NaN
# 3  1129100532  1129100532  ABRAHAM    EUGENE        NaN     JR
# 4  1128947343  1128947343    ACKER   RICHARD      BRYAN    NaN
#
#                                        ADDRESS        CHECK-IN  PRECINCT  \
# 0  5872 OLD JACKSONVILLE HWY #921, TYLER 75703  10/22/18 17:03     38.01
# 1      2051 W CUMBERLAND RD #1103, TYLER 75703  10/22/18 12:52     71.01
# 2              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:47     25.01
# 3              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:49     25.01
# 4             415 W RIECK RD #220, TYLER 75703  10/22/18 10:07     54.01
#
#                 SITE  BALLOT STYLE PARTY            POLLWORKER    CATEGORY
# 0               MAIN            25    NP  General Pollworker 2  Electronic
# 1  HERITAGE BUILDING            25    NP  General Pollworker 3  Electronic
# 2  HERITAGE BUILDING            20    NP  General Pollworker 1  Electronic
# 3  HERITAGE BUILDING            20    NP  General Pollworker 1  Electronic
# 4               MAIN            25    NP  General Pollworker 3  Electronic

# %%
ev_1022.tail(5)
# Out:
#               ID        CERT     LASTNAME   FIRSTNAME MIDDLENAME SUFFIX  \
# 4958  2002308280  2002308280        ZEMER  CHRISTOPER   FREDRICK    NaN
# 4959  1128395421  1128395421        ZEPPA   PRISCILLA      PRATT    NaN
# 4960  1016714491  1016714491       ZETTEL      CONNIE    HUBBARD    NaN
# 4961  2145876345  2145876345  ZIEGELBAUER     JUANITA     ELAINE    NaN
# 4962  1128892628  1128892628         ZORN       LAURA      ELLEN    NaN
#
#                                ADDRESS        CHECK-IN  PRECINCT  \
# 4958          1497 FM 724, TYLER 75704  10/22/18 14:27     44.03
# 4959         3502 MATT LN, TYLER 75701  10/22/18 11:51     50.01
# 4960    1659 FROSTWOOD DR, TYLER 75703  10/22/18 14:11     40.07
# 4961  104 LEGENDS CT #C, LINDALE 75771   10/22/18 8:44      5.16
# 4962    1202 RICE RD #110, TYLER 75703  10/22/18 15:59     54.01
#
#                             SITE  BALLOT STYLE PARTY            POLLWORKER  \
# 4958           HERITAGE BUILDING            25    NP  General Pollworker 1
# 4959  WHITEHOUSE MUNICIPAL COURT            25    NP  General Pollworker 1
# 4960    NOONDAY COMMUNITY CENTER            25    NP  General Pollworker 3
# 4961    NOONDAY COMMUNITY CENTER             4    NP  General Pollworker 2
# 4962                        MAIN            25    NP  General Pollworker 3
#
#         CATEGORY
# 4958  Electronic
# 4959  Electronic
# 4960  Electronic
# 4961  Electronic
# 4962  Electronic

# %%
# Find out the length of one of the tables (i.e. how many voters that day)
len(ev_1022)
# Out:
# 4963

# %%
# The pandas equivalent of Excel's transpose 
ev_1022.T
# Out:
#                                                      0     \
# ID                                             1205658124
# CERT                                           1205658124
# LASTNAME                                            ABBEY
# FIRSTNAME                                             IAN
# MIDDLENAME                                         ISSARA
# SUFFIX                                                NaN
# ADDRESS       5872 OLD JACKSONVILLE HWY #921, TYLER 75703
# CHECK-IN                                   10/22/18 17:03
# PRECINCT                                            38.01
# SITE                                                 MAIN
# BALLOT STYLE                                           25
# PARTY                                                  NP
# POLLWORKER                           General Pollworker 2
# CATEGORY                                       Electronic
#
#                                                  1     \
# ID                                         1057082649
# CERT                                       1057082649
# LASTNAME                                         ABEL
# FIRSTNAME                                       PAULA
# MIDDLENAME                                       ROSE
# SUFFIX                                            NaN
# ADDRESS       2051 W CUMBERLAND RD #1103, TYLER 75703
# CHECK-IN                               10/22/18 12:52
# PRECINCT                                        71.01
# SITE                                HERITAGE BUILDING
# BALLOT STYLE                                       25
# PARTY                                              NP
# POLLWORKER                       General Pollworker 3
# CATEGORY                                   Electronic
#
#                                          2     \
# ID                                 1129020391
# CERT                               1129020391
# LASTNAME                              ABRAHAM
# FIRSTNAME                               CAROL
# MIDDLENAME                                ANN
# SUFFIX                                    NaN
# ADDRESS       5212 GLEN ABBEY LN, TYLER 75703
# CHECK-IN                       10/22/18 11:47
# PRECINCT                                25.01
# SITE                        HERITAGE BUILDING
# BALLOT STYLE                               20
# PARTY                                      NP
# POLLWORKER               General Pollworker 1
# CATEGORY                           Electronic
#
#                                          3     \
# ID                                 1129100532
# CERT                               1129100532
# LASTNAME                              ABRAHAM
# FIRSTNAME                              EUGENE
# MIDDLENAME                                NaN
# SUFFIX                                     JR
# ADDRESS       5212 GLEN ABBEY LN, TYLER 75703
# CHECK-IN                       10/22/18 11:49
# PRECINCT                                25.01
# SITE                        HERITAGE BUILDING
# BALLOT STYLE                               20
# PARTY                                      NP
# POLLWORKER               General Pollworker 1
# CATEGORY                           Electronic
#
#                                           4     \
# ID                                  1128947343
# CERT                                1128947343
# LASTNAME                                 ACKER
# FIRSTNAME                              RICHARD
# MIDDLENAME                               BRYAN
# SUFFIX                                     NaN
# ADDRESS       415 W RIECK RD #220, TYLER 75703
# CHECK-IN                        10/22/18 10:07
# PRECINCT                                 54.01
# SITE                                      MAIN
# BALLOT STYLE                                25
# PARTY                                       NP
# POLLWORKER                General Pollworker 3
# CATEGORY                            Electronic
#
#                                              5     \
# ID                                     1128228140
# CERT                                   1128228140
# LASTNAME                                      ACY
# FIRSTNAME                                   KAREY
# MIDDLENAME                                    DON
# SUFFIX                                        NaN
# ADDRESS       10215 COUNTY ROAD 41, LINDALE 75771
# CHECK-IN                            10/22/18 8:22
# PRECINCT                                    14.09
# SITE                     NOONDAY COMMUNITY CENTER
# BALLOT STYLE                                   15
# PARTY                                          NP
# POLLWORKER                   General Pollworker 2
# CATEGORY                               Electronic
#
#                                                6     \
# ID                                       1129122969
# CERT                                     1129122969
# LASTNAME                                        ACY
# FIRSTNAME                                    ROBERT
# MIDDLENAME                                        C
# SUFFIX                                          NaN
# ADDRESS       20402 COUNTY ROAD 4114, LINDALE 75771
# CHECK-IN                              10/22/18 8:49
# PRECINCT                                       5.12
# SITE                       NOONDAY COMMUNITY CENTER
# BALLOT STYLE                                      4
# PARTY                                            NP
# POLLWORKER                     General Pollworker 2
# CATEGORY                                 Electronic
#
#                                      7                            8     \
# ID                             1128228164                   1128110606
# CERT                           1128228164                   1128110606
# LASTNAME                            ADAIR                        ADAIR
# FIRSTNAME                          FAVIAN                         MARY
# MIDDLENAME                         MURELL                        JOANN
# SUFFIX                                 JR                          NaN
# ADDRESS       206 CLEMSON DR, TYLER 75703  206 CLEMSON DR, TYLER 75703
# CHECK-IN                    10/22/18 9:33                10/22/18 9:32
# PRECINCT                            59.01                        59.01
# SITE           WHITEHOUSE MUNICIPAL COURT   WHITEHOUSE MUNICIPAL COURT
# BALLOT STYLE                           20                           20
# PARTY                                  NP                           NP
# POLLWORKER           General Pollworker 1         General Pollworker 1
# CATEGORY                       Electronic                   Electronic
#
#                                         9     ...  \
# ID                                1128688676  ...
# CERT                              1128688676  ...
# LASTNAME                               ADAMS  ...
# FIRSTNAME                             ANDREW  ...
# MIDDLENAME                             JAMES  ...
# SUFFIX                                   NaN  ...
# ADDRESS       303 HARMONY LN, HIDEAWAY 75771  ...
# CHECK-IN                      10/22/18 16:56  ...
# PRECINCT                               15.01  ...
# SITE               EV LINDALE PUBLIC LIBRARY  ...
# BALLOT STYLE                               4  ...
# PARTY                                     NP  ...
# POLLWORKER              General Pollworker 2  ...
# CATEGORY                          Electronic  ...
#
#                                         4953  \
# ID                                1174368370
# CERT                              1174368370
# LASTNAME                              ZAVALA
# FIRSTNAME                             CARLOS
# MIDDLENAME                             JAIME
# SUFFIX                                    JR
# ADDRESS       7373 FLAT ROCK LN, TYLER 75703
# CHECK-IN                      10/22/18 12:48
# PRECINCT                               71.02
# SITE                                    MAIN
# BALLOT STYLE                              25
# PARTY                                     NP
# POLLWORKER              General Pollworker 2
# CATEGORY                          Electronic
#
#                                           4954  \
# ID                                  1011626073
# CERT                                1011626073
# LASTNAME                                  ZEID
# FIRSTNAME                               YASSER
# MIDDLENAME                               FAHMY
# SUFFIX                                     NaN
# ADDRESS       763 HAMPTON HILL DR, TYLER 75703
# CHECK-IN                        10/22/18 12:39
# PRECINCT                                 59.01
# SITE                                      MAIN
# BALLOT STYLE                                20
# PARTY                                       NP
# POLLWORKER                General Pollworker 2
# CATEGORY                            Electronic
#
#                                             4955  \
# ID                                    1130376468
# CERT                                  1130376468
# LASTNAME                                 ZEINERT
# FIRSTNAME                                DEBORAH
# MIDDLENAME                                   KAY
# SUFFIX                                       NaN
# ADDRESS       9354 SAINT PATRICK PL, TYLER 75703
# CHECK-IN                          10/22/18 11:16
# PRECINCT                                   71.02
# SITE                    NOONDAY COMMUNITY CENTER
# BALLOT STYLE                                  25
# PARTY                                         NP
# POLLWORKER                  General Pollworker 1
# CATEGORY                              Electronic
#
#                                             4956  \
# ID                                    1130344690
# CERT                                  1130344690
# LASTNAME                                 ZEINERT
# FIRSTNAME                                   NEIL
# MIDDLENAME                                  JACK
# SUFFIX                                       NaN
# ADDRESS       9354 SAINT PATRICK PL, TYLER 75703
# CHECK-IN                          10/22/18 11:16
# PRECINCT                                   71.02
# SITE                    NOONDAY COMMUNITY CENTER
# BALLOT STYLE                                  25
# PARTY                                         NP
# POLLWORKER                  General Pollworker 1
# CATEGORY                              Electronic
#
#                                       4957                      4958  \
# ID                              1027911363                2002308280
# CERT                            1027911363                2002308280
# LASTNAME                            ZELLER                     ZEMER
# FIRSTNAME                          DELANNE                CHRISTOPER
# MIDDLENAME                             NaN                  FREDRICK
# SUFFIX                                 NaN                       NaN
# ADDRESS       3729 WOODS BLVD, TYLER 75707  1497 FM 724, TYLER 75704
# CHECK-IN                    10/22/18 17:04            10/22/18 14:27
# PRECINCT                             56.01                     44.03
# SITE                                  MAIN         HERITAGE BUILDING
# BALLOT STYLE                            22                        25
# PARTY                                   NP                        NP
# POLLWORKER            General Pollworker 3      General Pollworker 1
# CATEGORY                        Electronic                Electronic
#
#                                     4959                            4960  \
# ID                            1128395421                      1016714491
# CERT                          1128395421                      1016714491
# LASTNAME                           ZEPPA                          ZETTEL
# FIRSTNAME                      PRISCILLA                          CONNIE
# MIDDLENAME                         PRATT                         HUBBARD
# SUFFIX                               NaN                             NaN
# ADDRESS        3502 MATT LN, TYLER 75701  1659 FROSTWOOD DR, TYLER 75703
# CHECK-IN                  10/22/18 11:51                  10/22/18 14:11
# PRECINCT                           50.01                           40.07
# SITE          WHITEHOUSE MUNICIPAL COURT        NOONDAY COMMUNITY CENTER
# BALLOT STYLE                          25                              25
# PARTY                                 NP                              NP
# POLLWORKER          General Pollworker 1            General Pollworker 3
# CATEGORY                      Electronic                      Electronic
#
#                                           4961                            4962
# ID                                  2145876345                      1128892628
# CERT                                2145876345                      1128892628
# LASTNAME                           ZIEGELBAUER                            ZORN
# FIRSTNAME                              JUANITA                           LAURA
# MIDDLENAME                              ELAINE                           ELLEN
# SUFFIX                                     NaN                             NaN
# ADDRESS       104 LEGENDS CT #C, LINDALE 75771  1202 RICE RD #110, TYLER 75703
# CHECK-IN                         10/22/18 8:44                  10/22/18 15:59
# PRECINCT                                  5.16                           54.01
# SITE                  NOONDAY COMMUNITY CENTER                            MAIN
# BALLOT STYLE                                 4                              25
# PARTY                                       NP                              NP
# POLLWORKER                General Pollworker 2            General Pollworker 3
# CATEGORY                            Electronic                      Electronic
#
# [14 rows x 4963 columns]

# %%
# Smooshing together all the early voting data
# This is like copying and pasting them together, quickly 
frames = [ev_1022, ev_1023, ev_1024, ev_1025, ev_1026, ev_1027, ev_1029, ev_1030, ev_1031, ev_1101, ev_1102]
ev_2018 = pd.concat(frames, sort=False)

# %%
# Show me the top of my new dataframe
ev_2018.head(5)
# Out:
#              ID          CERT LASTNAME FIRSTNAME MIDDLENAME SUFFIX  \
# 0  1.205658e+09  1.205658e+09    ABBEY       IAN     ISSARA    NaN
# 1  1.057083e+09  1.057083e+09     ABEL     PAULA       ROSE    NaN
# 2  1.129020e+09  1.129020e+09  ABRAHAM     CAROL        ANN    NaN
# 3  1.129101e+09  1.129101e+09  ABRAHAM    EUGENE        NaN     JR
# 4  1.128947e+09  1.128947e+09    ACKER   RICHARD      BRYAN    NaN
#
#                                        ADDRESS        CHECK-IN  PRECINCT  \
# 0  5872 OLD JACKSONVILLE HWY #921, TYLER 75703  10/22/18 17:03     38.01
# 1      2051 W CUMBERLAND RD #1103, TYLER 75703  10/22/18 12:52     71.01
# 2              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:47     25.01
# 3              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:49     25.01
# 4             415 W RIECK RD #220, TYLER 75703  10/22/18 10:07     54.01
#
#                 SITE  ...  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0               MAIN  ...         NaN        NaN        NaN        NaN
# 1  HERITAGE BUILDING  ...         NaN        NaN        NaN        NaN
# 2  HERITAGE BUILDING  ...         NaN        NaN        NaN        NaN
# 3  HERITAGE BUILDING  ...         NaN        NaN        NaN        NaN
# 4               MAIN  ...         NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 29 columns]

# %%
# Tell me the length of my new dataframe 
# This is how many people voted early in Smith County 
len(ev_2018)
# Out:
# 48758

# %%
# Delete the columbs we don't need 
del ev_2018['CERT']
del ev_2018['PARTY']
del ev_2018['POLLWORKER']
del ev_2018['CATEGORY']

# %%
ev_2018.head(5)
# Out:
#              ID LASTNAME FIRSTNAME MIDDLENAME SUFFIX  \
# 0  1.205658e+09    ABBEY       IAN     ISSARA    NaN
# 1  1.057083e+09     ABEL     PAULA       ROSE    NaN
# 2  1.129020e+09  ABRAHAM     CAROL        ANN    NaN
# 3  1.129101e+09  ABRAHAM    EUGENE        NaN     JR
# 4  1.128947e+09    ACKER   RICHARD      BRYAN    NaN
#
#                                        ADDRESS        CHECK-IN  PRECINCT  \
# 0  5872 OLD JACKSONVILLE HWY #921, TYLER 75703  10/22/18 17:03     38.01
# 1      2051 W CUMBERLAND RD #1103, TYLER 75703  10/22/18 12:52     71.01
# 2              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:47     25.01
# 3              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:49     25.01
# 4             415 W RIECK RD #220, TYLER 75703  10/22/18 10:07     54.01
#
#                 SITE  BALLOT STYLE  ... Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0               MAIN          25.0  ...        NaN        NaN        NaN
# 1  HERITAGE BUILDING          25.0  ...        NaN        NaN        NaN
# 2  HERITAGE BUILDING          20.0  ...        NaN        NaN        NaN
# 3  HERITAGE BUILDING          20.0  ...        NaN        NaN        NaN
# 4               MAIN          25.0  ...        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 14
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 25 columns]

# %%
del ev_2018['Unnamed: 1']
del ev_2018['Unnamed: 2']
del ev_2018['Unnamed: 3']
del ev_2018['Unnamed: 4']
del ev_2018['Unnamed: 5']
del ev_2018['Unnamed: 6']
del ev_2018['Unnamed: 7']
del ev_2018['Unnamed: 8']
del ev_2018['Unnamed: 9']
del ev_2018['Unnamed: 10']
del ev_2018['Unnamed: 11']
del ev_2018['Unnamed: 12']
del ev_2018['Unnamed: 13']
del ev_2018['Unnamed: 14']

# %%
ev_2018.head(5)
# Out:
#              ID LASTNAME FIRSTNAME MIDDLENAME SUFFIX  \
# 0  1.205658e+09    ABBEY       IAN     ISSARA    NaN
# 1  1.057083e+09     ABEL     PAULA       ROSE    NaN
# 2  1.129020e+09  ABRAHAM     CAROL        ANN    NaN
# 3  1.129101e+09  ABRAHAM    EUGENE        NaN     JR
# 4  1.128947e+09    ACKER   RICHARD      BRYAN    NaN
#
#                                        ADDRESS        CHECK-IN  PRECINCT  \
# 0  5872 OLD JACKSONVILLE HWY #921, TYLER 75703  10/22/18 17:03     38.01
# 1      2051 W CUMBERLAND RD #1103, TYLER 75703  10/22/18 12:52     71.01
# 2              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:47     25.01
# 3              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:49     25.01
# 4             415 W RIECK RD #220, TYLER 75703  10/22/18 10:07     54.01
#
#                 SITE  BALLOT STYLE  \
# 0               MAIN          25.0
# 1  HERITAGE BUILDING          25.0
# 2  HERITAGE BUILDING          20.0
# 3  HERITAGE BUILDING          20.0
# 4               MAIN          25.0
#
#   Voted Early 10/25/2018 \nIllegal use of Registered Voter Lists - Election Code 18.008:  Current law provides that a person commits a Class A misdemeanor if the person \nuses information obtained from a registration list in connection with advertising or promoting commercial services or products.\n
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Change the name of columns because of that SUPER lengthy one
# I couldn't figure out how to delete it so this will do 
ev_2018.columns = ['voterid', 'lastname', 'firstname', 'middle', 'suffix', 'address', 'checkin', 'precinct', 'site', 'ballotstyle', 'misc']

# %%
ev_2018.head(5)
# Out:
#         voterid lastname firstname  middle suffix  \
# 0  1.205658e+09    ABBEY       IAN  ISSARA    NaN
# 1  1.057083e+09     ABEL     PAULA    ROSE    NaN
# 2  1.129020e+09  ABRAHAM     CAROL     ANN    NaN
# 3  1.129101e+09  ABRAHAM    EUGENE     NaN     JR
# 4  1.128947e+09    ACKER   RICHARD   BRYAN    NaN
#
#                                        address         checkin  precinct  \
# 0  5872 OLD JACKSONVILLE HWY #921, TYLER 75703  10/22/18 17:03     38.01
# 1      2051 W CUMBERLAND RD #1103, TYLER 75703  10/22/18 12:52     71.01
# 2              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:47     25.01
# 3              5212 GLEN ABBEY LN, TYLER 75703  10/22/18 11:49     25.01
# 4             415 W RIECK RD #220, TYLER 75703  10/22/18 10:07     54.01
#
#                 site  ballotstyle misc
# 0               MAIN         25.0  NaN
# 1  HERITAGE BUILDING         25.0  NaN
# 2  HERITAGE BUILDING         20.0  NaN
# 3  HERITAGE BUILDING         20.0  NaN
# 4               MAIN         25.0  NaN

# %%
ev_2018.to_csv(r'EarlyVoters2018.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c03c42b5acf4> in <module>
# ----> 1 ev_2018.to_csv(r'EarlyVoters2018.csv')
#
# NameError: name 'ev_2018' is not defined
